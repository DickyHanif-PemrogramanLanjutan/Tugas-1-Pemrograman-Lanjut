# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('zoo.csv' , delimiter = ',')
# Out:
#     Unnamed: 0    animal  uniq_id  water_need
# 0            0  elephant     1001         500
# 1            1  elephant     1002         600
# 2            2  elephant     1003         550
# 3            3     tiger     1004         300
# 4            4     tiger     1005         320
# 5            5     tiger     1006         330
# 6            6     tiger     1007         290
# 7            7     tiger     1008         310
# 8            8     zebra     1009         200
# 9            9     zebra     1010         220
# 10          10     zebra     1011         240
# 11          11     zebra     1012         230
# 12          12     zebra     1013         220
# 13          13     zebra     1014         100
# 14          14     zebra     1015          80
# 15          15      lion     1016         420
# 16          16      lion     1017         600
# 17          17      lion     1018         500
# 18          18      lion     1019         390
# ...

# %%
pd.read_csv('zoo_eats.csv' , delimiter = ';')
# Out:
#             ,animal,food
# 0  0,elephant,vegetables
# 1           1,tiger,meat
# 2  2,kangaroo,vegetables
# 3     3,zebra,vegetables
# 4    4,giraffe,vegetable

# %%
zoo_eats = pd.read_csv('zoo_eats.csv' , delimiter = ';')

# %%
zoo = pd.read_csv('zoo.csv' , delimiter = ',')

# %%
zoo.sort_values('water_need')
# Out:
#     Unnamed: 0    animal  uniq_id  water_need
# 14          14     zebra     1015          80
# 13          13     zebra     1014         100
# 8            8     zebra     1009         200
# 9            9     zebra     1010         220
# 12          12     zebra     1013         220
# 11          11     zebra     1012         230
# 10          10     zebra     1011         240
# 6            6     tiger     1007         290
# 3            3     tiger     1004         300
# 7            7     tiger     1008         310
# 4            4     tiger     1005         320
# 5            5     tiger     1006         330
# 18          18      lion     1019         390
# 19          19  kangaroo     1020         410
# 21          21  kangaroo     1022         410
# 15          15      lion     1016         420
# 20          20  kangaroo     1021         430
# 17          17      lion     1018         500
# 0            0  elephant     1001         500
# ...

# %%
zoo.sort_values(by=['animal','water_need'])
# Out:
#     Unnamed: 0    animal  uniq_id  water_need
# 0            0  elephant     1001         500
# 2            2  elephant     1003         550
# 1            1  elephant     1002         600
# 19          19  kangaroo     1020         410
# 21          21  kangaroo     1022         410
# 20          20  kangaroo     1021         430
# 18          18      lion     1019         390
# 15          15      lion     1016         420
# 17          17      lion     1018         500
# 16          16      lion     1017         600
# 6            6     tiger     1007         290
# 3            3     tiger     1004         300
# 7            7     tiger     1008         310
# 4            4     tiger     1005         320
# 5            5     tiger     1006         330
# 14          14     zebra     1015          80
# 13          13     zebra     1014         100
# 8            8     zebra     1009         200
# 9            9     zebra     1010         220
# ...

# %%
zoo.sort_values('water_need', ascending = False)
# Out:
#     Unnamed: 0    animal  uniq_id  water_need
# 1            1  elephant     1002         600
# 16          16      lion     1017         600
# 2            2  elephant     1003         550
# 0            0  elephant     1001         500
# 17          17      lion     1018         500
# 20          20  kangaroo     1021         430
# 15          15      lion     1016         420
# 19          19  kangaroo     1020         410
# 21          21  kangaroo     1022         410
# 18          18      lion     1019         390
# 5            5     tiger     1006         330
# 4            4     tiger     1005         320
# 7            7     tiger     1008         310
# 3            3     tiger     1004         300
# 6            6     tiger     1007         290
# 10          10     zebra     1011         240
# 11          11     zebra     1012         230
# 9            9     zebra     1010         220
# 12          12     zebra     1013         220
# ...

# %%
zoo.sort_values('water_need', ascending = False).reset_index(drop = True)
# Out:
#     Unnamed: 0    animal  uniq_id  water_need
# 0            1  elephant     1002         600
# 1           16      lion     1017         600
# 2            2  elephant     1003         550
# 3            0  elephant     1001         500
# 4           17      lion     1018         500
# 5           20  kangaroo     1021         430
# 6           15      lion     1016         420
# 7           19  kangaroo     1020         410
# 8           21  kangaroo     1022         410
# 9           18      lion     1019         390
# 10           5     tiger     1006         330
# 11           4     tiger     1005         320
# 12           7     tiger     1008         310
# 13           3     tiger     1004         300
# 14           6     tiger     1007         290
# 15          10     zebra     1011         240
# 16          11     zebra     1012         230
# 17           9     zebra     1010         220
# 18          12     zebra     1013         220
# ...

# %%
# !wget 46.101.230.157/dilan/pandas_tutorial_buy.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pd.read_csv('pandas_tutorial_buy.csv', delimiter = ';', names = ['my_date_time', 'event', 'user_id', 'amount'])
# Out:
#                          my_date_time       event  user_id         amount
# 2018-01-01 00:01:01 read    country_7  2458151261      SEO  North America
# 2018-01-01 00:03:20 read    country_7  2458151262      SEO  South America
# 2018-01-01 00:04:01 read    country_7  2458151263  AdWords         Africa
# 2018-01-01 00:04:02 read    country_7  2458151264  AdWords         Europe
# 2018-01-01 00:05:03 read    country_8  2458151265   Reddit  North America
# 2018-01-01 00:05:42 read    country_6  2458151266   Reddit  North America
# 2018-01-01 00:06:06 read    country_2  2458151267   Reddit         Europe
# 2018-01-01 00:06:15 read    country_6  2458151268  AdWords         Europe
# 2018-01-01 00:07:21 read    country_7  2458151269  AdWords  North America
# 2018-01-01 00:07:29 read    country_5  2458151270   Reddit  North America
# 2018-01-01 00:07:57 read    country_5  2458151271  AdWords           Asia
# 2018-01-01 00:08:57 read    country_7  2458151272      SEO      Australia
# ...

# %%
blog_buy = pd.read_csv('pandas_tutorial_buy.csv', delimiter = ';', names = ['my_date_time', 'event', 'user_id', 'amount'])

# %%
article_read = pd.read_csv('pandas_tutorial_read.csv',delimiter = ';', names = ['my_datetime','event','country','user_id','source','topic'])

# %%
article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
blog_buy.sort_values(by = 'my_date_time')
# Out:
#                          my_date_time       event  user_id         amount
# 2018-01-01 18:01:11 read    country_1  2458152585      SEO         Europe
# 2018-01-01 15:46:00 read    country_1  2458152431      SEO  North America
# 2018-01-01 02:31:25 read    country_1  2458151436  AdWords         Europe
# 2018-01-01 12:40:25 read    country_1  2458152209  AdWords           Asia
# 2018-01-01 10:40:49 read    country_1  2458152052      SEO  South America
# 2018-01-01 05:13:09 read    country_1  2458151642      SEO  North America
# 2018-01-01 12:42:58 read    country_1  2458152216   Reddit      Australia
# 2018-01-01 05:47:29 read    country_1  2458151680  AdWords           Asia
# 2018-01-01 04:26:24 read    country_1  2458151597  AdWords  North America
# 2018-01-01 18:26:07 read    country_1  2458152623   Reddit         Africa
# 2018-01-01 23:13:57 read    country_1  2458152983  AdWords         Europe
# 2018-01-01 13:47:11 read    country_1  2458152287   Reddit           Asia
# ...

# %%
step_1 = article_read.merge(blog_buy, how = 'left', left_on = 'user_id', right_on = 'user_id')
step_2 = step_1.amount
step_3 = step_2.fillna(0)
result = step_3.mean()
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-c65e1c21cc18> in <module>
# ----> 1 step_1 = article_read.merge(blog_buy, how = 'left', left_on = 'user_id', right_on = 'user_id')
#       2 step_2 = step_1.amount
#       3 step_3 = step_2.fillna(0)
#       4 result = step_3.mean()
#       5 result
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
step_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-2c6e2981ad68> in <module>
# ----> 1 step_1
#
# NameError: name 'step_1' is not defined

# %%
step_1 = article_read.merge(blog_buy, how = 'left', left_on = 'user_id', right_on = 'user_id')
step_2 = step_1.fillna(0)
step_3 = step_2.groupby('country').sum()
step_4 = step_3.amount
step_5 = step_4.sort_values(ascending = False)
step_5.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-e4c6c04acef2> in <module>
# ----> 1 step_1 = article_read.merge(blog_buy, how = 'left', left_on = 'user_id', right_on = 'user_id')
#       2 step_2 = step_1.fillna(0)
#       3 step_3 = step_2.groupby('country').sum()
#       4 step_4 = step_3.amount
#       5 step_5 = step_4.sort_values(ascending = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ...
